# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuvraj9769/Data-science-1/blob/main/Data_science_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task - 2 : - Summarizing data with statistics

# %%
import pandas as pd

data = pd.DataFrame({"Roll no": [1,2,3,4,5],"Name": ["Yuvraj","Sarvan","Altaf","Vijay","Rahul"],"Marks": [85,25,25,40,25]})
data
# Out:
#    Roll no    Name  Marks
# 0        1  Yuvraj     85
# 1        2  Sarvan     25
# 2        3   Altaf     25
# 3        4   Vijay     40
# 4        5   Rahul     25

# %%
data.isnull().sum()
# Out:
# Roll no    0
# Name       0
# Marks      0
# dtype: int64

# %%
data.describe()
# Out:
#         Roll no      Marks
# count  5.000000   5.000000
# mean   3.000000  40.000000
# std    1.581139  25.980762
# min    1.000000  25.000000
# 25%    2.000000  25.000000
# 50%    3.000000  25.000000
# 75%    4.000000  40.000000
# max    5.000000  85.000000

# %%
data.describe(include = "object")
# Out:
#           Name
# count        5
# unique       5
# top     Yuvraj
# freq         1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  5 non-null      int64
#  1   Name     5 non-null      object
#  2   Marks    5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes

# %%
data.nunique()
# Out:
# Roll no    5
# Name       5
# Marks      3
# dtype: int64

# %%
data.duplicated("Marks").sum()
# Out:
# 2

# %%
data["Name"]
# Out:
# 0    Yuvraj
# 1    Sarvan
# 2     Altaf
# 3     Vijay
# 4     Rahul
# Name: Name, dtype: object

# %%
data.value_counts(data["Roll no"])
# Out:
# Roll no
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# dtype: int64

# %%
data.value_counts(data["Name"])
# Out:
# Name
# Altaf     1
# Rahul     1
# Sarvan    1
# Vijay     1
# Yuvraj    1
# dtype: int64

# %%
data.value_counts(data["Marks"])
# Out:
# Marks
# 25    3
# 40    1
# 85    1
# dtype: int64

# %%
data2 = pd.DataFrame({"Class": ["A","A","B","B","A","B"]})
data2
# Out:
#   Class
# 0     A
# 1     A
# 2     B
# 3     B
# 4     A
# 5     B

# %%
data2.nunique()
# Out:
# Class    2
# dtype: int64

# %%
data2.value_counts(data2["Class"])
# Out:
# Class
# A    3
# B    3
# dtype: int64

# %%
from statistics import mean

mean(data["Marks"])
# Out:
# 40

# %%
data.var()
# Out:
# <ipython-input-123-6bf595b3cfe5>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# Roll no      2.5
# Marks      675.0
# dtype: float64

# %%
corelation =  data.corr()
# Out:
# <ipython-input-124-715c729e422d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corelation =  data.corr()

# %%
import seaborn as sns

sns.heatmap(corelation,annot=True , fmt=".2f",cmap="viridis")
# Out:
# <Axes: >
